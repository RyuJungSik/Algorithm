# %%
s,n=input().split()
s=int(s)
answer=[[] for i in range(2*s+3)]

def makeOne(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][s+2-1]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]

def makeTwo(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(s+2,s+2+s):
        board[i][0]='|'
    for i in range(1,s+1):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for i in range(1,s+1):
        board[s+1][i]='-'
    for i in range(1,s+1):
        board[2*s+3-1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeThree(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][s+2-1]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for i in range(1,s+1):
        board[s+1][i]='-'
    for i in range(1,s+1):
        board[2*s+3-1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeFour(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][0]='|'
    for i in range(1,s+1):
        board[i][s+2-1]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[s+1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeFive(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][0]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for i in range(1,s+1):
        board[s+1][i]='-'
    for i in range(1,s+1):
        board[2*s+3-1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeSix(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][0]='|'
    for i in range(s+2,s+2+s):
        board[i][0]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for i in range(1,s+1):
        board[s+1][i]='-'
    for i in range(1,s+1):
        board[2*s+3-1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeSeven(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][s+2-1]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeEight(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][0]='|'
    for i in range(s+2,s+2+s):
        board[i][0]='|'
    for i in range(1,s+1):
        board[i][s+2-1]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for i in range(1,s+1):
        board[s+1][i]='-'
    for i in range(1,s+1):
        board[2*s+3-1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeNine(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][0]='|'
    for i in range(1,s+1):
        board[i][s+2-1]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for i in range(1,s+1):
        board[s+1][i]='-'
    for i in range(1,s+1):
        board[2*s+3-1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
def makeZero(s):
    global answer
    board=[[" "]*(s+2) for _ in range(2*s+3)]
    for i in range(1,s+1):
        board[i][0]='|'
    for i in range(s+2,s+2+s):
        board[i][0]='|'
    for i in range(1,s+1):
        board[i][s+2-1]='|'
    for i in range(s+2,s+2+s):
        board[i][s+2-1]='|'
        
    for i in range(1,s+1):
        board[0][i]='-'
    for i in range(1,s+1):
        board[2*s+3-1][i]='-'
    for idx,c in enumerate(board):
        answer[idx]=answer[idx]+c+[" "]
        
for c in n:
    if c=='1':
        makeOne(s)
    elif c=='2':
        makeTwo(s)
    elif c=='3':
        makeThree(s)
    elif c=='4':
        makeFour(s)
    elif c=='5':
        makeFive(s)
    elif c=='6':
        makeSix(s)
    elif c=='7':
        makeSeven(s)
    elif c=='8':
        makeEight(s)
    elif c=='9':
        makeNine(s)
    elif c=='0':
        makeZero(s)
for c in answer:
    print("".join(c))
