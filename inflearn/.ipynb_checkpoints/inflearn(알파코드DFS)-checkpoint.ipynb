# %%
def DFS(index, sum):
    if(index==len(n)):
        print(sum)
        return
    else:
        if index+1<len(n) and int(n[index+1])==0:
            DFS(index+2, sum+chr(64+int(n[index]+n[index+1])))
        else:
            DFS(index+1, sum+chr(64+int(n[index])))
        if(index+1<len(n) and int(n[index]+n[index+1])<27):
            DFS(index+2, sum+chr(64+int(n[index]+n[index+1])))
        
n=input()
DFS(0, "")
# Out:
# 115213102120131
# AAEBACJBATACA
# AAEBACJBATMA
# AAEBACJBATACA
# AAEBACJBATMA
# AAEBACJBL@ACA
# AAEBACJBL@MA
# AAEBACJBLACA
# AAEBACJUTACA
# AAEBACJUTMA
# AAEBACJUTACA
# AAEBACJUTMA
# AAEBACJBATACA
# AAEBACJBATMA
# AAEBACJBATACA
# AAEBACJBATMA
# AAEBACJBL@ACA
# AAEBACJBL@MA
# AAEBACJBLACA
# AAEBACJUTACA
# AAEBACJUTMA
# AAEBACJUTACA
# AAEBACJUTMA
# AAEBMJBATACA
# AAEBMJBATMA
# AAEBMJBATACA
# AAEBMJBATMA
# AAEBMJBL@ACA
# AAEBMJBL@MA
# AAEBMJBLACA
# AAEBMJUTACA
# AAEBMJUTMA
# AAEBMJUTACA
# AAEBMJUTMA
# AAEBMJBATACA
# AAEBMJBATMA
# AAEBMJBATACA
# AAEBMJBATMA
# AAEBMJBL@ACA
# AAEBMJBL@MA
# AAEBMJBLACA
# AAEBMJUTACA
# AAEBMJUTMA
# AAEBMJUTACA
# AAEBMJUTMA
# AAEUCJBATACA
# AAEUCJBATMA
# AAEUCJBATACA
# AAEUCJBATMA
# AAEUCJBL@ACA
# AAEUCJBL@MA
# AAEUCJBLACA
# AAEUCJUTACA
# AAEUCJUTMA
# AAEUCJUTACA
# AAEUCJUTMA
# AAEUCJBATACA
# AAEUCJBATMA
# AAEUCJBATACA
# AAEUCJBATMA
# AAEUCJBL@ACA
# AAEUCJBL@MA
# AAEUCJBLACA
# AAEUCJUTACA
# AAEUCJUTMA
# AAEUCJUTACA
# AAEUCJUTMA
# AOBACJBATACA
# AOBACJBATMA
# ...
